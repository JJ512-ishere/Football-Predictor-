# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
#index_col specifies the first column is just an index column
matches=pd.read_csv("matches.csv",index_col=0)

# %%
matches.shape
# Out:
# (1032, 27)

# %%
matches['team'].value_counts()
# Out:
# team
# Liverpool                   52
# Newcastle United            52
# Burnley                     52
# Nottingham Forest           52
# Brentford                   52
# Everton                     52
# Crystal Palace              52
# Fulham                      52
# Manchester City             52
# Sheffield United            52
# Wolverhampton Wanderers     52
# West Ham United             52
# Brighton and Hove Albion    52
# Manchester United           52
# Aston Villa                 52
# Arsenal                     52
# Bournemouth                 50
# Tottenham Hotspur           50
# Luton Town                  50
# Chelsea                     50
# Name: count, dtype: int64

# %%
#Nmodel can only work on columns with numerical types and not on object types
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches['date']=pd.to_datetime(matches['date'])

# %%
#Venue Code Predictor 
#Convert Home and Away to Numbers
#Code is 0 for away and 1 for home
matches['venue_code']=matches['venue'].astype("category").cat.codes

# %%
#Adding a code to each opponenent
matches['opp_code']=matches['opponent'].astype("category").cat.codes

# %%
#Removing the minutes from time and only getting the hour in type int
matches['hour']=matches['time'].str.replace(":.+","",regex=True).astype("int")

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1 2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2 2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3 2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4 2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...   fk  pk  pkatt  season       team venue_code opp_code  \
# 0        Chelsea  ...  0.0   0      0    2024  Liverpool          0        6
# 1    Bournemouth  ...  1.0   0      1    2024  Liverpool          1        2
# 2  Newcastle Utd  ...  1.0   0      0    2024  Liverpool          0       14
# 3    Aston Villa  ...  0.0   0      0    2024  Liverpool          1        1
# 4         Wolves  ...  0.0   0      0    2024  Liverpool          0       19
#
#   hour  day_code  target
# 0   16         6       0
# 1   15         5       1
# 2   16         6       1
# 3   14         6       1
# 4   12         5       1
#
# [5 rows x 32 columns]

# %%
#Assign a Number for Every Day of the Week
#dt day of week gets the day for each date 
matches['day_code']=matches['date'].dt.day_of_week

# %%
matches['target']=(matches['result']=="W").astype("int")

# %%
#Random Forest is series of descison trees with slightly different parameters
#min 10 samples then split 
#random state of 1 gives us same results as long as data is same 
rf=RandomForestClassifier(n_estimators=50,min_samples_split=10,random_state=1)

# %%
train=matches[matches['date']<'2024-01-01']

# %%
test=matches[matches['date']>'2024-01-01']

# %%
predictors=['venue_code','opp_code','hour','day_code']

# %%
#Fit the model using the predictors and find the target
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#Test the model using test data 
preds=rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
#Calculate the accuracy of the test data 
acc=accuracy_score(test['target'],preds)

# %%
acc
# Out:
# 0.5245901639344263

# %%
#Combine to see where probability for predicitons was highest
combined=pd.DataFrame(dict(actual=test['target'],prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           92  62
# 1           54  36

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.3673469387755102

# %%
#Groups the data my teams 
grouped_matches=matches.groupby("team")

# %%
#All of Man City Matches grouped by date 
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
#Computing rolling averages for each team
def rolling_averages(group,cols,new_cols):
    group=group.sort_values("date")
    #Closed=left ignores the current week
    rolling_stats=group[cols].rolling(3,closed='left').mean()
    group[new_cols]=rolling_stats
    group=group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]

# %%
#For new columns add the word rolling to the end of these columns 
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W  3.0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W  3.0
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W  3.0
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W  3.0
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W  3.0
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W  3.0
# 33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W  2.0
# 33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W  2.0
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D  1.0
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D  1.0
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W  1.0
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W  1.0
# 37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W  1.0
# 37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 3   0.0    Newcastle Utd  ...         5       1    2.333333    0.000000
# 4   1.0    Sheffield Utd  ...         6       1    1.666667    0.000000
# 4   1.0    Sheffield Utd  ...         6       1    1.333333    0.333333
# 5   1.0           Fulham  ...         5       1    1.666667    0.666667
# 5   1.0           Fulham  ...         5       1    3.000000    1.000000
# 6   1.0         West Ham  ...         5       1    4.000000    1.000000
# 6   1.0         West Ham  ...         5       1    4.333333    1.000000
# 8   0.0  Nott'ham Forest  ...         5       1    3.666667    1.000000
# 8   0.0  Nott'ham Forest  ...         5       1    2.666667    0.666667
# 10  2.0           Wolves  ...         5       0    2.333333    0.333333
# 10  2.0           Wolves  ...         5       0    1.666667    0.666667
# 12  1.0          Arsenal  ...         6       0    1.333333    1.333333
# 12  1.0          Arsenal  ...         6       0    0.666667    1.666667
# 13  1.0         Brighton  ...         5       1    0.333333    1.333333
# 13  1.0         Brighton  ...         5       1    0.666667    1.000000
# 15  0.0   Manchester Utd  ...         6       1    1.333333    1.000000
# 15  0.0   Manchester Utd  ...         6       1    2.333333    0.666667
# 16  1.0      Bournemouth  ...         5       1    2.666667    0.333333
ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0    0.0  Crystal Palace  ...         0       1    1.666667    0.666667
# 1    2.0          Fulham  ...         5       0    1.333333    0.333333
# 2    2.0          Fulham  ...         5       0    1.333333    0.666667
# 3    1.0  Manchester Utd  ...         6       1    1.666667    1.333333
# 4    1.0  Manchester Utd  ...         6       1    2.333333    1.666667
# ..   ...             ...  ...       ...     ...         ...         ...
# 967  2.0       Brentford  ...         5       0    2.666667    2.000000
# 968  1.0       Tottenham  ...         5       1    1.333333    2.000000
# 969  1.0       Tottenham  ...         5       1    0.666667    1.666667
# 970  0.0   Sheffield Utd  ...         6       1    1.333333    1.333333
# 971  0.0   Sheffield Utd  ...         6       1    1.666667    0.666667
#
#     sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0    14.333333    5.333333    18.200000   0.000000    0.333333       0.333333
# 1    13.666667    3.666667    17.300000   0.000000    0.666667       0.666667
# 2    14.666667    4.333333    15.533333   0.000000    1.000000       1.000000
# 3    16.333333    6.666667    14.666667   0.000000    1.000000       1.000000
# 4    17.666667    7.666667    14.200000   0.000000    0.666667       0.666667
# ..         ...         ...          ...        ...         ...            ...
# 967  14.333333    5.666667    16.800000   1.666667    0.666667       0.666667
# 968  15.666667    5.333333    17.000000   1.333333    0.333333       0.333333
# 969  15.333333    5.666667    16.766667   0.666667    0.000000       0.000000
# 970  13.666667    6.333333    16.333333   0.333333    0.000000       0.000000
# 971  12.333333    5.333333    15.466667   0.000000    0.000000       0.000000
#
# [972 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
#Get unique value for the index column for each row 
matches_rolling.index= range(matches_rolling.shape[0])

# %%
def make_predictions(data,predictors):
    train=data[data['date']<'2024-01-01']
    test=data[data['date']>'2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precison = precision_score(test["target"], preds)
    return combined,precison

# %%
combined,precison = make_predictions(matches_rolling, predictors + new_cols)

# %%
precison
# Out:
# 0.5340909090909091

# %%
combined
# Out:
#      actual  predicted
# 37        1          1
# 38        1          0
# 39        1          0
# 40        1          1
# 41        1          1
# ..      ...        ...
# 967       0          1
# 968       1          0
# 969       1          0
# 970       1          0
# 971       1          0
#
# [244 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted       date                     team         opponent  \
# 37        1          1 2024-01-20                  Arsenal   Crystal Palace
# 38        1          0 2024-01-20                  Arsenal   Crystal Palace
# 39        1          0 2024-01-30                  Arsenal  Nott'ham Forest
# 40        1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 41        1          1 2024-02-04                  Arsenal        Liverpool
# ..      ...        ...        ...                      ...              ...
# 967       0          1 2024-02-10  Wolverhampton Wanderers        Brentford
# 968       1          0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 969       1          0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 970       1          0 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
# 971       1          0 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
#
#     result
# 37       W
# 38       W
# 39       W
# 40       W
# 41       W
# ..     ...
# 967      L
# 968      W
# 969      W
# 970      W
# 971      W
#
# [244 rows x 6 columns]

# %%
#Some team names are different in oponents and the actual team name 
#Retruns same value if same name in both columns
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#      actual  predicted       date                     team         opponent  \
# 37        1          1 2024-01-20                  Arsenal   Crystal Palace
# 38        1          0 2024-01-20                  Arsenal   Crystal Palace
# 39        1          0 2024-01-30                  Arsenal  Nott'ham Forest
# 40        1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 41        1          1 2024-02-04                  Arsenal        Liverpool
# ..      ...        ...        ...                      ...              ...
# 967       0          1 2024-02-10  Wolverhampton Wanderers        Brentford
# 968       1          0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 969       1          0 2024-02-17  Wolverhampton Wanderers        Tottenham
# 970       1          0 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
# 971       1          0 2024-02-25  Wolverhampton Wanderers    Sheffield Utd
#
#     result new_team
# 37       W  Arsenal
# 38       W  Arsenal
# 39       W  Arsenal
# 40       W  Arsenal
# 41       W  Arsenal
# ..     ...      ...
# 967      L   Wolves
# 968      W   Wolves
# 969      W   Wolves
# 970      W   Wolves
# 971      W   Wolves
#
# [244 rows x 7 columns]

# %%
#Merge the data frame with itself so the same match is not shown twice from both sides 
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            1 2024-01-20                  Arsenal
# 1           1            1 2024-01-20                  Arsenal
# 2           1            0 2024-01-20                  Arsenal
# 3           1            0 2024-01-20                  Arsenal
# 4           1            0 2024-01-30                  Arsenal
# ..        ...          ...        ...                      ...
# 435         1            0 2024-02-17  Wolverhampton Wanderers
# 436         1            0 2024-02-25  Wolverhampton Wanderers
# 437         1            0 2024-02-25  Wolverhampton Wanderers
# 438         1            0 2024-02-25  Wolverhampton Wanderers
# 439         1            0 2024-02-25  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Crystal Palace        W    Arsenal         0            0
# 1     Crystal Palace        W    Arsenal         0            0
# 2     Crystal Palace        W    Arsenal         0            0
# 3     Crystal Palace        W    Arsenal         0            0
# 4    Nott'ham Forest        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 435        Tottenham        W     Wolves         0            1
# 436    Sheffield Utd        W     Wolves         0            0
# 437    Sheffield Utd        W     Wolves         0            0
# 438    Sheffield Utd        W     Wolves         0            0
# 439    Sheffield Utd        W     Wolves         0            0
#
#                 team_y opponent_y result_y         new_team_y
# 0       Crystal Palace    Arsenal        L     Crystal Palace
# 1       Crystal Palace    Arsenal        L     Crystal Palace
# 2       Crystal Palace    Arsenal        L     Crystal Palace
# 3       Crystal Palace    Arsenal        L     Crystal Palace
# 4    Nottingham Forest    Arsenal        L  Nottingham Forest
# ..                 ...        ...      ...                ...
# 435  Tottenham Hotspur     Wolves        L          Tottenham
# 436   Sheffield United     Wolves        L   Sheffield United
# 437   Sheffield United     Wolves        L   Sheffield United
# 438   Sheffield United     Wolves        L   Sheffield United
# 439   Sheffield United     Wolves        L   Sheffield United
#
# [440 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    72
# 0    50
# Name: count, dtype: int64

# %%
72/122
# Out:
# 0.5901639344262295
